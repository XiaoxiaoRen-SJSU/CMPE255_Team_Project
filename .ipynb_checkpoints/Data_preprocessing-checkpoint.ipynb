# %%
import pandas as pd

acquisitions = pd.read_csv("./data/crunchbase-acquisitions.csv")
acquisitions.head()
# Out:
#        company_permalink  company_name company_category_code  \
# 0  /company/1000memories  1000memories                   web
# 1       /company/100plus       100Plus             analytics
# 2        /company/10best        10best                   web
# 3        /company/10east        10East       network_hosting
# 4     /company/12society     12Society             ecommerce
#
#   company_country_code company_state_code company_region    company_city  \
# 0                  USA                 CA         SF Bay   San Francisco
# 1                  USA                 CA         SF Bay   San Francisco
# 2                  USA                 SC     Greenville      Greenville
# 3                  USA                 FL   Jacksonville    Jacksonville
# 4                  USA                 CA    Los Angeles  West Hollywood
#
#             acquirer_permalink       acquirer_name acquirer_category_code  \
# 0        /company/ancestry-com            Ancestry              ecommerce
# 1     /company/practice-fusion     Practice Fusion                 health
# 2          /company/nile-guide           NileGuide                 travel
# 3  /company/railcar-management  Railcar Management             enterprise
# 4           /company/quarterly           Quarterly                    web
#
#   acquirer_country_code acquirer_state_code acquirer_region   acquirer_city  \
# 0                   USA                  UT  Salt Lake City           Provo
# 1                   USA                  CA          SF Bay   San Francisco
# 2                   USA                  CA          SF Bay   San Francisco
# 3                   NaN                 NaN         unknown             NaN
# 4                   USA                  CA     Los Angeles  West Hollywood
#
#   acquired_at acquired_month acquired_quarter  acquired_year  price_amount  \
# 0   10/3/2012        2012-10          2012-Q4           2012           NaN
# 1   2/27/2013        2013-02          2013-Q1           2013           NaN
# 2   1/25/2011        2011-01          2011-Q1           2011           NaN
# 3   4/14/2009        2009-04          2009-Q2           2009           NaN
# 4    7/3/2013        2013-07          2013-Q3           2013           NaN
#
#   price_currency_code
# 0                 USD
# 1                 USD
# 2                 USD
# 3                 USD
# 4                 USD

# %%
companies = pd.read_csv("./data/crunchbase-companies.csv")
companies.head()
# Out:
#                 permalink           name category_code funding_total_usd  \
# 0        /company/waywire       #waywire          news           1750000
# 1        /company/n-plusn         #NAME?      software            600000
# 2   /company/club-domains  .Club Domains      software           7000000
# 3         /company/0xdata         0xdata     analytics           1700000
# 4  /company/1-800-dentist  1-800-DENTIST        health               NaN
#
#       status country_code state_code           region           city  \
# 0  operating          USA         NY         New York       New York
# 1  operating          USA         NY         New York       New York
# 2  operating          USA         FL  Fort Lauderdale   Oakland Park
# 3  operating          USA         CA           SF Bay  Mountain View
# 4  operating          USA         CA      Los Angeles    Los Angeles
#
#    funding_rounds  founded_at founded_month founded_quarter  founded_year  \
# 0               1    6/1/2012       2012-06         2012-Q2        2012.0
# 1               1    1/1/2012       2012-01         2012-Q1        2012.0
# 2               1  10/10/2011       2011-10         2011-Q4        2011.0
# 3               1         NaN           NaN             NaN           NaN
# 4               1    1/1/1986       1986-01         1986-Q1        1986.0
#
#   first_funding_at last_funding_at last_milestone_at
# 0        6/30/2012       6/30/2012          9/6/2013
# 1        8/29/2012       8/29/2012               NaN
# 2        5/31/2013       5/31/2013               NaN
# 3         1/3/2013        1/3/2013          1/1/2012
# 4        8/19/2010       8/19/2010         8/19/2010

# %%
investments = pd.read_csv("./data/crunchbase-investments.csv")
investments.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x8f in position 3: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-4-18a9dec74be5> in <module>
# ----> 1 investments = pd.read_csv("./data/crunchbase-investments.csv")
#       2 investments.head()
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     433
#     434     try:
# --> 435         data = parser.read(nrows)
#     436     finally:
#     437         parser.close()
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1137     def read(self, nrows=None):
#    1138         nrows = _validate_integer('nrows', nrows)
# -> 1139         ret = self._engine.read(nrows)
#    1140
#    1141         # May alter columns / col_dict
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1993     def read(self, nrows=None):
#    1994         try:
# -> 1995             data = self._reader.read(nrows)
#    1996         except StopIteration:
#    1997             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x8f in position 3: invalid start byte

# %%
rounds = pd.read_csv("./data/crunchbase-rounds.csv")
rounds.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa6 in position 4: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-6-a5e4e80c1b23> in <module>
# ----> 1 rounds = pd.read_csv("./data/crunchbase-rounds.csv")
#       2 rounds.head()
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     433
#     434     try:
# --> 435         data = parser.read(nrows)
#     436     finally:
#     437         parser.close()
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1137     def read(self, nrows=None):
#    1138         nrows = _validate_integer('nrows', nrows)
# -> 1139         ret = self._engine.read(nrows)
#    1140
#    1141         # May alter columns / col_dict
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1993     def read(self, nrows=None):
#    1994         try:
# -> 1995             data = self._reader.read(nrows)
#    1996         except StopIteration:
#    1997             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa6 in position 4: invalid start byte
